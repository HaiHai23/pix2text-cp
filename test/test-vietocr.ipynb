# %%
import matplotlib.pyplot as plt
from PIL import Image

from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg

# %%
config = Cfg.load_config_from_name('vgg_transformer')

# %%
config['cnn']['pretrained']=False
config['device'] = 'cpu'

# %%
detector = Predictor(config)
# Out:
# d:\Apps\Anaconda3\envs\ai\Lib\site-packages\torch\nn\modules\transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Model weight C:\Users\admin\AppData\Local\Temp\vgg_transformer.pth exsits. Ignore download!

# %%
img = Image.open(r"C:\Users\admin\Pictures\Screenshots\Screenshot 2024-11-01 100252.png")

# %%
s = detector.predict(img)
s
# Out:
# '1. Kiến thức 6,7,8 quan trọng cần nhớ'

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1362x830>
